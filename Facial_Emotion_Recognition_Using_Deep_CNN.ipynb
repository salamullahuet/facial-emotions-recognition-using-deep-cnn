# %% [markdown]
# # Connect google Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # Import Libraries

# %%
import matplotlib.pyplot as plt

import numpy as np
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split

from keras.models import Sequential #Initialise neural network model as a sequential network
from keras.layers import Conv2D #Convolution operation
from keras.layers.normalization import BatchNormalization
from keras.regularizers import l2
from keras.layers import Activation#Applies activation function
from keras.layers import Dropout#Prevents overfitting by randomly converting few outputs to zero
from keras.layers import MaxPooling2D # Maxpooling function
from keras.layers import Flatten # Converting 2D arrays into a 1D linear vector
from keras.layers import Dense # Regular fully connected neural network
from keras import optimizers
from keras.callbacks import ReduceLROnPlateau, EarlyStopping, TensorBoard, ModelCheckpoint
from sklearn.metrics import accuracy_score

# %%
def load_data(dataset_path):
  
  #classes = ['Angry', 'Disgust', 'Fear', 'Happy', 'Sad', 'Surprsie', 'Neutral']  #We will be dealing with seven different types of emotions.

  data = []
  test_data = []
  test_labels = []
  labels =[]

  with open(dataset_path, 'r') as file:
      for line_no, line in enumerate(file.readlines()):
          if 0 < line_no <= 35887:
            curr_class, line, set_type = line.split(',')
            image_data = np.asarray([int(x) for x in line.split()]).reshape(48, 48) #Creating a list out of the string then converting it into a 2-Dimensional numpy array.
            image_data =image_data.astype(np.uint8)/255.0
            
            if (set_type.strip() == 'PrivateTest'):
              
              test_data.append(image_data)
              test_labels.append(curr_class)
            else:
              data.append(image_data)
              labels.append(curr_class)
      
      test_data = np.expand_dims(test_data, -1)
      test_labels = to_categorical(test_labels, num_classes = 7)
      data = np.expand_dims(data, -1)   
      labels = to_categorical(labels, num_classes = 7)
    
      return np.array(data), np.array(labels), np.array(test_data), np.array(test_labels)

# %% [markdown]
# # Load the data

# %%
dataset_path = "/content/gdrive/My Drive/fer2013.csv" 
train_data, train_labels, test_data, test_labels = load_data(dataset_path)
#train_data, test_data, train_labels, test_labels = train_test_split(data, labels, test_size = test_size,random_state = seed)

print("Number of images in Training set:", len(train_data))
print("Number of images in Test set:", len(test_data))
# Out:
# Number of images in Training set: 32298
# Number of images in Test set: 3589

# %% [markdown]
# # Define and Deploy the neural network

# %%
epochs = 100
batch_size = 64
learning_rate = 0.001


model = Sequential()
    
model.add(Conv2D(64, (3, 3), activation='relu', input_shape=(48, 48, 1), kernel_regularizer=l2(0.01)))
model.add(Conv2D(64, (3, 3), padding='same',activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2), strides=(2, 2)))
model.add(Dropout(0.5))
    
model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.5))
    
model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.5))
    
model.add(Conv2D(512, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(512, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(512, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.5))
    
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(7, activation='softmax'))
adam = optimizers.Adam(lr = learning_rate)
model.compile(optimizer = adam, loss = 'categorical_crossentropy', metrics = ['accuracy'])
    
print(model.summary())

lr_reducer = ReduceLROnPlateau(monitor='val_loss', factor=0.9, patience=3)
early_stopper = EarlyStopping(monitor='val_acc', min_delta=0, patience=6, mode='auto')
checkpointer = ModelCheckpoint('/content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5', monitor='val_loss', verbose=1, save_best_only=True)

model_info=model.fit(
                       train_data,
                      train_labels,
                      epochs = epochs,
                      batch_size = batch_size,
                      validation_split = 0.2,
                      shuffle = True,
                      callbacks=[lr_reducer, checkpointer, early_stopper]
                      )
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 46, 46, 64)        640
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 46, 46, 64)        36928
# _________________________________________________________________
# batch_normalization (BatchNo (None, 46, 46, 64)        256
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 23, 23, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 23, 23, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 23, 23, 128)       73856
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 23, 23, 128)       512
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 23, 23, 128)       147584
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 23, 23, 128)       512
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 23, 23, 128)       147584
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 23, 23, 128)       512
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 11, 11, 128)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 11, 11, 128)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 11, 11, 256)       295168
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 11, 11, 256)       1024
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 11, 11, 256)       590080
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 11, 11, 256)       1024
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 11, 11, 256)       590080
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 11, 11, 256)       1024
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 5, 5, 256)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 5, 5, 256)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 5, 5, 512)         1180160
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 5, 5, 512)         2048
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 5, 5, 512)         2359808
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 5, 5, 512)         2048
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 5, 5, 512)         2359808
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 5, 5, 512)         2048
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 2, 2, 512)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 2, 2, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               1049088
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 7)                 455
# =================================================================
# Total params: 9,014,727
# Trainable params: 9,009,223
# Non-trainable params: 5,504
# _________________________________________________________________
# None
# Epoch 1/100
# 404/404 [==============================] - ETA: 0s - loss: 2.0986 - accuracy: 0.2004
# Epoch 00001: val_loss improved from inf to 1.85267, saving model to /content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 30s 73ms/step - loss: 2.0986 - accuracy: 0.2004 - val_loss: 1.8527 - val_accuracy: 0.2489
# Epoch 2/100
# 403/404 [============================>.] - ETA: 0s - loss: 1.8681 - accuracy: 0.2343
# Epoch 00002: val_loss improved from 1.85267 to 1.83809, saving model to /content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 29s 72ms/step - loss: 1.8679 - accuracy: 0.2343 - val_loss: 1.8381 - val_accuracy: 0.2489
# Epoch 3/100
# 403/404 [============================>.] - ETA: 0s - loss: 1.8406 - accuracy: 0.2478
# Epoch 00003: val_loss improved from 1.83809 to 1.82840, saving model to /content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 30s 74ms/step - loss: 1.8407 - accuracy: 0.2478 - val_loss: 1.8284 - val_accuracy: 0.2489
# Epoch 4/100
# 403/404 [============================>.] - ETA: 0s - loss: 1.8328 - accuracy: 0.2491
# Epoch 00004: val_loss improved from 1.82840 to 1.82182, saving model to /content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 30s 74ms/step - loss: 1.8327 - accuracy: 0.2491 - val_loss: 1.8218 - val_accuracy: 0.2489
# Epoch 5/100
# 403/404 [============================>.] - ETA: 0s - loss: 1.8245 - accuracy: 0.2511
# Epoch 00005: val_loss improved from 1.82182 to 1.80752, saving model to /content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 30s 75ms/step - loss: 1.8243 - accuracy: 0.2512 - val_loss: 1.8075 - val_accuracy: 0.2498
# Epoch 6/100
# 403/404 [============================>.] - ETA: 0s - loss: 1.8156 - accuracy: 0.2522
# Epoch 00006: val_loss did not improve from 1.80752
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 63ms/step - loss: 1.8156 - accuracy: 0.2523 - val_loss: 1.8213 - val_accuracy: 0.2489
# Epoch 7/100
# 403/404 [============================>.] - ETA: 0s - loss: 1.8026 - accuracy: 0.2568
# Epoch 00007: val_loss did not improve from 1.80752
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 62ms/step - loss: 1.8024 - accuracy: 0.2568 - val_loss: 1.8093 - val_accuracy: 0.2491
# Epoch 8/100
# 403/404 [============================>.] - ETA: 0s - loss: 1.7647 - accuracy: 0.2768
# Epoch 00008: val_loss improved from 1.80752 to 1.70821, saving model to /content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 30s 75ms/step - loss: 1.7649 - accuracy: 0.2768 - val_loss: 1.7082 - val_accuracy: 0.2980
# Epoch 9/100
# 403/404 [============================>.] - ETA: 0s - loss: 1.7228 - accuracy: 0.2993
# Epoch 00009: val_loss did not improve from 1.70821
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 62ms/step - loss: 1.7226 - accuracy: 0.2992 - val_loss: 1.7402 - val_accuracy: 0.2946
# Epoch 10/100
# 403/404 [============================>.] - ETA: 0s - loss: 1.6855 - accuracy: 0.3132
# Epoch 00010: val_loss improved from 1.70821 to 1.69999, saving model to /content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 30s 75ms/step - loss: 1.6856 - accuracy: 0.3131 - val_loss: 1.7000 - val_accuracy: 0.3094
# Epoch 11/100
# 403/404 [============================>.] - ETA: 0s - loss: 1.6283 - accuracy: 0.3310
# Epoch 00011: val_loss improved from 1.69999 to 1.61171, saving model to /content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 30s 74ms/step - loss: 1.6283 - accuracy: 0.3311 - val_loss: 1.6117 - val_accuracy: 0.3433
# Epoch 12/100
# 403/404 [============================>.] - ETA: 0s - loss: 1.5864 - accuracy: 0.3677
# Epoch 00012: val_loss improved from 1.61171 to 1.60658, saving model to /content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 30s 75ms/step - loss: 1.5863 - accuracy: 0.3679 - val_loss: 1.6066 - val_accuracy: 0.3373
# Epoch 13/100
# 403/404 [============================>.] - ETA: 0s - loss: 1.5365 - accuracy: 0.3911
# Epoch 00013: val_loss improved from 1.60658 to 1.57633, saving model to /content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 30s 74ms/step - loss: 1.5361 - accuracy: 0.3912 - val_loss: 1.5763 - val_accuracy: 0.3630
# Epoch 14/100
# 403/404 [============================>.] - ETA: 0s - loss: 1.5002 - accuracy: 0.4057
# Epoch 00014: val_loss improved from 1.57633 to 1.50359, saving model to /content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 30s 74ms/step - loss: 1.5003 - accuracy: 0.4057 - val_loss: 1.5036 - val_accuracy: 0.3808
# Epoch 15/100
# 403/404 [============================>.] - ETA: 0s - loss: 1.4685 - accuracy: 0.4206
# Epoch 00015: val_loss did not improve from 1.50359
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 62ms/step - loss: 1.4685 - accuracy: 0.4206 - val_loss: 1.5216 - val_accuracy: 0.3875
# Epoch 16/100
# 403/404 [============================>.] - ETA: 0s - loss: 1.4449 - accuracy: 0.4241
# Epoch 00016: val_loss improved from 1.50359 to 1.36762, saving model to /content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 30s 75ms/step - loss: 1.4454 - accuracy: 0.4242 - val_loss: 1.3676 - val_accuracy: 0.4288
# Epoch 17/100
# 403/404 [============================>.] - ETA: 0s - loss: 1.4185 - accuracy: 0.4314
# Epoch 00017: val_loss did not improve from 1.36762
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 62ms/step - loss: 1.4183 - accuracy: 0.4315 - val_loss: 1.3791 - val_accuracy: 0.4392
# Epoch 18/100
# 403/404 [============================>.] - ETA: 0s - loss: 1.4003 - accuracy: 0.4406
# Epoch 00018: val_loss did not improve from 1.36762
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 62ms/step - loss: 1.4004 - accuracy: 0.4404 - val_loss: 1.4163 - val_accuracy: 0.4381
# Epoch 19/100
# 403/404 [============================>.] - ETA: 0s - loss: 1.3833 - accuracy: 0.4459
# Epoch 00019: val_loss improved from 1.36762 to 1.34333, saving model to /content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 30s 74ms/step - loss: 1.3836 - accuracy: 0.4458 - val_loss: 1.3433 - val_accuracy: 0.4676
# Epoch 20/100
# 403/404 [============================>.] - ETA: 0s - loss: 1.3715 - accuracy: 0.4505
# Epoch 00020: val_loss improved from 1.34333 to 1.33959, saving model to /content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 30s 73ms/step - loss: 1.3720 - accuracy: 0.4505 - val_loss: 1.3396 - val_accuracy: 0.4687
# Epoch 21/100
# 403/404 [============================>.] - ETA: 0s - loss: 1.3530 - accuracy: 0.4677
# Epoch 00021: val_loss did not improve from 1.33959
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 62ms/step - loss: 1.3527 - accuracy: 0.4679 - val_loss: 1.6264 - val_accuracy: 0.3506
# Epoch 22/100
# 403/404 [============================>.] - ETA: 0s - loss: 1.3322 - accuracy: 0.4794
# Epoch 00022: val_loss improved from 1.33959 to 1.28256, saving model to /content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 30s 74ms/step - loss: 1.3321 - accuracy: 0.4792 - val_loss: 1.2826 - val_accuracy: 0.5116
# Epoch 23/100
# 403/404 [============================>.] - ETA: 0s - loss: 1.3119 - accuracy: 0.4962
# Epoch 00023: val_loss did not improve from 1.28256
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 62ms/step - loss: 1.3119 - accuracy: 0.4962 - val_loss: 1.3082 - val_accuracy: 0.4964
# Epoch 24/100
# 403/404 [============================>.] - ETA: 0s - loss: 1.2896 - accuracy: 0.5083
# Epoch 00024: val_loss improved from 1.28256 to 1.25646, saving model to /content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 30s 74ms/step - loss: 1.2896 - accuracy: 0.5081 - val_loss: 1.2565 - val_accuracy: 0.5255
# Epoch 25/100
# 403/404 [============================>.] - ETA: 0s - loss: 1.2667 - accuracy: 0.5154
# Epoch 00025: val_loss did not improve from 1.25646
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 61ms/step - loss: 1.2666 - accuracy: 0.5155 - val_loss: 1.2925 - val_accuracy: 0.5105
# Epoch 26/100
# 403/404 [============================>.] - ETA: 0s - loss: 1.2451 - accuracy: 0.5319
# Epoch 00026: val_loss did not improve from 1.25646
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 61ms/step - loss: 1.2450 - accuracy: 0.5319 - val_loss: 1.2686 - val_accuracy: 0.5262
# Epoch 27/100
# 403/404 [============================>.] - ETA: 0s - loss: 1.2192 - accuracy: 0.5395
# Epoch 00027: val_loss improved from 1.25646 to 1.21126, saving model to /content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 30s 73ms/step - loss: 1.2191 - accuracy: 0.5396 - val_loss: 1.2113 - val_accuracy: 0.5495
# Epoch 28/100
# 403/404 [============================>.] - ETA: 0s - loss: 1.2029 - accuracy: 0.5471
# Epoch 00028: val_loss improved from 1.21126 to 1.19720, saving model to /content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 30s 74ms/step - loss: 1.2029 - accuracy: 0.5468 - val_loss: 1.1972 - val_accuracy: 0.5483
# Epoch 29/100
# 403/404 [============================>.] - ETA: 0s - loss: 1.1744 - accuracy: 0.5592
# Epoch 00029: val_loss improved from 1.19720 to 1.17155, saving model to /content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 30s 74ms/step - loss: 1.1745 - accuracy: 0.5592 - val_loss: 1.1715 - val_accuracy: 0.5630
# Epoch 30/100
# 403/404 [============================>.] - ETA: 0s - loss: 1.1635 - accuracy: 0.5636
# Epoch 00030: val_loss improved from 1.17155 to 1.16804, saving model to /content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 30s 74ms/step - loss: 1.1638 - accuracy: 0.5635 - val_loss: 1.1680 - val_accuracy: 0.5647
# Epoch 31/100
# 403/404 [============================>.] - ETA: 0s - loss: 1.1466 - accuracy: 0.5717
# Epoch 00031: val_loss did not improve from 1.16804
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 61ms/step - loss: 1.1465 - accuracy: 0.5716 - val_loss: 1.2916 - val_accuracy: 0.5307
# Epoch 32/100
# 403/404 [============================>.] - ETA: 0s - loss: 1.1254 - accuracy: 0.5827
# Epoch 00032: val_loss improved from 1.16804 to 1.14633, saving model to /content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 30s 74ms/step - loss: 1.1257 - accuracy: 0.5827 - val_loss: 1.1463 - val_accuracy: 0.5745
# Epoch 33/100
# 403/404 [============================>.] - ETA: 0s - loss: 1.0968 - accuracy: 0.5947
# Epoch 00033: val_loss did not improve from 1.14633
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 61ms/step - loss: 1.0971 - accuracy: 0.5947 - val_loss: 1.2421 - val_accuracy: 0.5658
# Epoch 34/100
# 403/404 [============================>.] - ETA: 0s - loss: 1.0799 - accuracy: 0.5998
# Epoch 00034: val_loss did not improve from 1.14633
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 61ms/step - loss: 1.0800 - accuracy: 0.5997 - val_loss: 1.3024 - val_accuracy: 0.5094
# Epoch 35/100
# 403/404 [============================>.] - ETA: 0s - loss: 1.0751 - accuracy: 0.6082
# Epoch 00035: val_loss did not improve from 1.14633
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 61ms/step - loss: 1.0756 - accuracy: 0.6083 - val_loss: 1.2180 - val_accuracy: 0.5582
# Epoch 36/100
# 403/404 [============================>.] - ETA: 0s - loss: 1.0457 - accuracy: 0.6175
# Epoch 00036: val_loss did not improve from 1.14633
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 61ms/step - loss: 1.0458 - accuracy: 0.6174 - val_loss: 1.1696 - val_accuracy: 0.5695
# Epoch 37/100
# 403/404 [============================>.] - ETA: 0s - loss: 1.0106 - accuracy: 0.6308
# Epoch 00037: val_loss improved from 1.14633 to 1.13801, saving model to /content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Colab Notebooks/fer2/weights.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 30s 73ms/step - loss: 1.0104 - accuracy: 0.6310 - val_loss: 1.1380 - val_accuracy: 0.5964
# Epoch 38/100
# 403/404 [============================>.] - ETA: 0s - loss: 0.9925 - accuracy: 0.6411
# Epoch 00038: val_loss did not improve from 1.13801
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 61ms/step - loss: 0.9928 - accuracy: 0.6406 - val_loss: 1.1439 - val_accuracy: 0.5988
# Epoch 39/100
# 403/404 [============================>.] - ETA: 0s - loss: 0.9685 - accuracy: 0.6482
# Epoch 00039: val_loss did not improve from 1.13801
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 62ms/step - loss: 0.9688 - accuracy: 0.6480 - val_loss: 1.1620 - val_accuracy: 0.5978
# Epoch 40/100
# 403/404 [============================>.] - ETA: 0s - loss: 0.9535 - accuracy: 0.6596
# Epoch 00040: val_loss did not improve from 1.13801
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 61ms/step - loss: 0.9536 - accuracy: 0.6596 - val_loss: 1.2181 - val_accuracy: 0.5859
# Epoch 41/100
# 403/404 [============================>.] - ETA: 0s - loss: 0.9282 - accuracy: 0.6664
# Epoch 00041: val_loss did not improve from 1.13801
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 61ms/step - loss: 0.9282 - accuracy: 0.6665 - val_loss: 1.1386 - val_accuracy: 0.6037
# Epoch 42/100
# 403/404 [============================>.] - ETA: 0s - loss: 0.8898 - accuracy: 0.6800
# Epoch 00042: val_loss did not improve from 1.13801
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 61ms/step - loss: 0.8899 - accuracy: 0.6800 - val_loss: 1.1927 - val_accuracy: 0.6022
# Epoch 43/100
# 403/404 [============================>.] - ETA: 0s - loss: 0.8758 - accuracy: 0.6883
# Epoch 00043: val_loss did not improve from 1.13801
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 61ms/step - loss: 0.8755 - accuracy: 0.6882 - val_loss: 1.2649 - val_accuracy: 0.5763
# Epoch 44/100
# 403/404 [============================>.] - ETA: 0s - loss: 0.8589 - accuracy: 0.6992
# Epoch 00044: val_loss did not improve from 1.13801
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 61ms/step - loss: 0.8587 - accuracy: 0.6992 - val_loss: 1.1664 - val_accuracy: 0.6130
# Epoch 45/100
# 403/404 [============================>.] - ETA: 0s - loss: 0.8345 - accuracy: 0.7061
# Epoch 00045: val_loss did not improve from 1.13801
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 61ms/step - loss: 0.8343 - accuracy: 0.7061 - val_loss: 1.1747 - val_accuracy: 0.6088
# Epoch 46/100
# 403/404 [============================>.] - ETA: 0s - loss: 0.8269 - accuracy: 0.7100
# Epoch 00046: val_loss did not improve from 1.13801
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 61ms/step - loss: 0.8270 - accuracy: 0.7098 - val_loss: 1.1824 - val_accuracy: 0.6153
# Epoch 47/100
# 403/404 [============================>.] - ETA: 0s - loss: 0.8022 - accuracy: 0.7200
# Epoch 00047: val_loss did not improve from 1.13801
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 61ms/step - loss: 0.8021 - accuracy: 0.7199 - val_loss: 1.2278 - val_accuracy: 0.6068
# Epoch 48/100
# 403/404 [============================>.] - ETA: 0s - loss: 0.7645 - accuracy: 0.7319
# Epoch 00048: val_loss did not improve from 1.13801
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 61ms/step - loss: 0.7645 - accuracy: 0.7319 - val_loss: 1.2994 - val_accuracy: 0.6051
# Epoch 49/100
# 403/404 [============================>.] - ETA: 0s - loss: 0.7516 - accuracy: 0.7365
# Epoch 00049: val_loss did not improve from 1.13801
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 61ms/step - loss: 0.7516 - accuracy: 0.7364 - val_loss: 1.3089 - val_accuracy: 0.6195
# Epoch 50/100
# 403/404 [============================>.] - ETA: 0s - loss: 0.7286 - accuracy: 0.7469
# Epoch 00050: val_loss did not improve from 1.13801
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 61ms/step - loss: 0.7283 - accuracy: 0.7469 - val_loss: 1.3824 - val_accuracy: 0.6144
# Epoch 51/100
# 403/404 [============================>.] - ETA: 0s - loss: 0.7059 - accuracy: 0.7554
# Epoch 00051: val_loss did not improve from 1.13801
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 62ms/step - loss: 0.7059 - accuracy: 0.7554 - val_loss: 1.3340 - val_accuracy: 0.6206
# Epoch 52/100
# 403/404 [============================>.] - ETA: 0s - loss: 0.6904 - accuracy: 0.7621
# Epoch 00052: val_loss did not improve from 1.13801
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 62ms/step - loss: 0.6909 - accuracy: 0.7619 - val_loss: 1.3043 - val_accuracy: 0.6181
# Epoch 53/100
# 403/404 [============================>.] - ETA: 0s - loss: 0.6757 - accuracy: 0.7678
# Epoch 00053: val_loss did not improve from 1.13801
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 62ms/step - loss: 0.6761 - accuracy: 0.7676 - val_loss: 1.3637 - val_accuracy: 0.6105
# Epoch 54/100
# 403/404 [============================>.] - ETA: 0s - loss: 0.6446 - accuracy: 0.7758
# Epoch 00054: val_loss did not improve from 1.13801
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 61ms/step - loss: 0.6448 - accuracy: 0.7756 - val_loss: 1.3937 - val_accuracy: 0.6300
# Epoch 55/100
# 403/404 [============================>.] - ETA: 0s - loss: 0.6309 - accuracy: 0.7831
# Epoch 00055: val_loss did not improve from 1.13801
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 61ms/step - loss: 0.6308 - accuracy: 0.7831 - val_loss: 1.4323 - val_accuracy: 0.6231
# Epoch 56/100
# 403/404 [============================>.] - ETA: 0s - loss: 0.6078 - accuracy: 0.7921
# Epoch 00056: val_loss did not improve from 1.13801
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 61ms/step - loss: 0.6077 - accuracy: 0.7921 - val_loss: 1.4207 - val_accuracy: 0.6336
# Epoch 57/100
# 403/404 [============================>.] - ETA: 0s - loss: 0.5894 - accuracy: 0.7996
# Epoch 00057: val_loss did not improve from 1.13801
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 61ms/step - loss: 0.5894 - accuracy: 0.7997 - val_loss: 1.4622 - val_accuracy: 0.6266
# Epoch 58/100
# 403/404 [============================>.] - ETA: 0s - loss: 0.5748 - accuracy: 0.8059
# Epoch 00058: val_loss did not improve from 1.13801
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 61ms/step - loss: 0.5743 - accuracy: 0.8061 - val_loss: 1.5368 - val_accuracy: 0.6073
# Epoch 59/100
# 403/404 [============================>.] - ETA: 0s - loss: 0.5612 - accuracy: 0.8116
# Epoch 00059: val_loss did not improve from 1.13801
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 61ms/step - loss: 0.5612 - accuracy: 0.8116 - val_loss: 1.5261 - val_accuracy: 0.6341
# Epoch 60/100
# 403/404 [============================>.] - ETA: 0s - loss: 0.5517 - accuracy: 0.8143
# Epoch 00060: val_loss did not improve from 1.13801
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 61ms/step - loss: 0.5515 - accuracy: 0.8143 - val_loss: 1.4702 - val_accuracy: 0.6183
# Epoch 61/100
# 403/404 [============================>.] - ETA: 0s - loss: 0.5326 - accuracy: 0.8206
# Epoch 00061: val_loss did not improve from 1.13801
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 62ms/step - loss: 0.5326 - accuracy: 0.8205 - val_loss: 1.5726 - val_accuracy: 0.6308
# Epoch 62/100
# 403/404 [============================>.] - ETA: 0s - loss: 0.5080 - accuracy: 0.8308
# Epoch 00062: val_loss did not improve from 1.13801
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 61ms/step - loss: 0.5079 - accuracy: 0.8307 - val_loss: 1.6471 - val_accuracy: 0.6251
# Epoch 63/100
# 403/404 [============================>.] - ETA: 0s - loss: 0.5001 - accuracy: 0.8323
# Epoch 00063: val_loss did not improve from 1.13801
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 61ms/step - loss: 0.5001 - accuracy: 0.8324 - val_loss: 1.5668 - val_accuracy: 0.6259
# Epoch 64/100
# 403/404 [============================>.] - ETA: 0s - loss: 0.4871 - accuracy: 0.8367
# Epoch 00064: val_loss did not improve from 1.13801
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 61ms/step - loss: 0.4871 - accuracy: 0.8366 - val_loss: 1.6337 - val_accuracy: 0.6282
# Epoch 65/100
# 403/404 [============================>.] - ETA: 0s - loss: 0.4712 - accuracy: 0.8431
# Epoch 00065: val_loss did not improve from 1.13801
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 62ms/step - loss: 0.4713 - accuracy: 0.8430 - val_loss: 1.7012 - val_accuracy: 0.6320
# Epoch 66/100
# 403/404 [============================>.] - ETA: 0s - loss: 0.4613 - accuracy: 0.8504
# Epoch 00066: val_loss did not improve from 1.13801
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 61ms/step - loss: 0.4614 - accuracy: 0.8504 - val_loss: 1.6639 - val_accuracy: 0.6325
# Epoch 67/100
# 403/404 [============================>.] - ETA: 0s - loss: 0.4432 - accuracy: 0.8544
# Epoch 00067: val_loss did not improve from 1.13801
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 61ms/step - loss: 0.4430 - accuracy: 0.8544 - val_loss: 1.8134 - val_accuracy: 0.6373
# Epoch 68/100
# 403/404 [============================>.] - ETA: 0s - loss: 0.4341 - accuracy: 0.8572
# Epoch 00068: val_loss did not improve from 1.13801
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 61ms/step - loss: 0.4340 - accuracy: 0.8573 - val_loss: 1.8864 - val_accuracy: 0.6330
# Epoch 69/100
# 403/404 [============================>.] - ETA: 0s - loss: 0.4268 - accuracy: 0.8606
# Epoch 00069: val_loss did not improve from 1.13801
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 61ms/step - loss: 0.4266 - accuracy: 0.8607 - val_loss: 1.7401 - val_accuracy: 0.6370
# Epoch 70/100
# 403/404 [============================>.] - ETA: 0s - loss: 0.4050 - accuracy: 0.8694
# Epoch 00070: val_loss did not improve from 1.13801
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 61ms/step - loss: 0.4049 - accuracy: 0.8694 - val_loss: 1.9397 - val_accuracy: 0.6339
# Epoch 71/100
# 403/404 [============================>.] - ETA: 0s - loss: 0.4033 - accuracy: 0.8711
# Epoch 00071: val_loss did not improve from 1.13801
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 61ms/step - loss: 0.4032 - accuracy: 0.8710 - val_loss: 1.8132 - val_accuracy: 0.6354
# Epoch 72/100
# 403/404 [============================>.] - ETA: 0s - loss: 0.3870 - accuracy: 0.8712
# Epoch 00072: val_loss did not improve from 1.13801
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 61ms/step - loss: 0.3871 - accuracy: 0.8710 - val_loss: 2.0047 - val_accuracy: 0.6327
# Epoch 73/100
# 403/404 [============================>.] - ETA: 0s - loss: 0.3802 - accuracy: 0.8789
# Epoch 00073: val_loss did not improve from 1.13801
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 61ms/step - loss: 0.3802 - accuracy: 0.8789 - val_loss: 1.9378 - val_accuracy: 0.6347
# Epoch 74/100
# 403/404 [============================>.] - ETA: 0s - loss: 0.3720 - accuracy: 0.8813
# Epoch 00074: val_loss did not improve from 1.13801
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 61ms/step - loss: 0.3722 - accuracy: 0.8812 - val_loss: 2.0125 - val_accuracy: 0.6395
# Epoch 75/100
# 403/404 [============================>.] - ETA: 0s - loss: 0.3631 - accuracy: 0.8822
# Epoch 00075: val_loss did not improve from 1.13801
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 61ms/step - loss: 0.3629 - accuracy: 0.8823 - val_loss: 2.0443 - val_accuracy: 0.6396
# Epoch 76/100
# 403/404 [============================>.] - ETA: 0s - loss: 0.3549 - accuracy: 0.8866
# Epoch 00076: val_loss did not improve from 1.13801
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 61ms/step - loss: 0.3552 - accuracy: 0.8864 - val_loss: 2.0767 - val_accuracy: 0.6362
# Epoch 77/100
# 403/404 [============================>.] - ETA: 0s - loss: 0.3460 - accuracy: 0.8893
# Epoch 00077: val_loss did not improve from 1.13801
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 61ms/step - loss: 0.3458 - accuracy: 0.8893 - val_loss: 2.0694 - val_accuracy: 0.6285
# Epoch 78/100
# 403/404 [============================>.] - ETA: 0s - loss: 0.3388 - accuracy: 0.8917
# Epoch 00078: val_loss did not improve from 1.13801
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 62ms/step - loss: 0.3392 - accuracy: 0.8916 - val_loss: 2.0807 - val_accuracy: 0.6330
# Epoch 79/100
# 403/404 [============================>.] - ETA: 0s - loss: 0.3273 - accuracy: 0.8951
# Epoch 00079: val_loss did not improve from 1.13801
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 61ms/step - loss: 0.3276 - accuracy: 0.8949 - val_loss: 2.0196 - val_accuracy: 0.6358
# Epoch 80/100
# 403/404 [============================>.] - ETA: 0s - loss: 0.3267 - accuracy: 0.8948
# Epoch 00080: val_loss did not improve from 1.13801
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 61ms/step - loss: 0.3267 - accuracy: 0.8948 - val_loss: 2.1626 - val_accuracy: 0.6392
# Epoch 81/100
# 403/404 [============================>.] - ETA: 0s - loss: 0.3122 - accuracy: 0.8991
# Epoch 00081: val_loss did not improve from 1.13801
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 61ms/step - loss: 0.3121 - accuracy: 0.8991 - val_loss: 2.2503 - val_accuracy: 0.6412
# Epoch 82/100
# 403/404 [============================>.] - ETA: 0s - loss: 0.3102 - accuracy: 0.8996
# Epoch 00082: val_loss did not improve from 1.13801
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 61ms/step - loss: 0.3102 - accuracy: 0.8996 - val_loss: 2.3064 - val_accuracy: 0.6362
# Epoch 83/100
# 403/404 [============================>.] - ETA: 0s - loss: 0.2964 - accuracy: 0.9034
# Epoch 00083: val_loss did not improve from 1.13801
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 61ms/step - loss: 0.2967 - accuracy: 0.9033 - val_loss: 2.3457 - val_accuracy: 0.6385
# Epoch 84/100
# 403/404 [============================>.] - ETA: 0s - loss: 0.2943 - accuracy: 0.9065
# Epoch 00084: val_loss did not improve from 1.13801
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 61ms/step - loss: 0.2946 - accuracy: 0.9064 - val_loss: 2.2232 - val_accuracy: 0.6365
# Epoch 85/100
# 403/404 [============================>.] - ETA: 0s - loss: 0.2917 - accuracy: 0.9069
# Epoch 00085: val_loss did not improve from 1.13801
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 61ms/step - loss: 0.2915 - accuracy: 0.9070 - val_loss: 2.2199 - val_accuracy: 0.6376
# Epoch 86/100
# 403/404 [============================>.] - ETA: 0s - loss: 0.2782 - accuracy: 0.9134
# Epoch 00086: val_loss did not improve from 1.13801
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 61ms/step - loss: 0.2783 - accuracy: 0.9133 - val_loss: 2.3802 - val_accuracy: 0.6395
# Epoch 87/100
# 403/404 [============================>.] - ETA: 0s - loss: 0.2740 - accuracy: 0.9125
# Epoch 00087: val_loss did not improve from 1.13801
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 61ms/step - loss: 0.2741 - accuracy: 0.9125 - val_loss: 2.3387 - val_accuracy: 0.6354
# Epoch 88/100
# 403/404 [============================>.] - ETA: 0s - loss: 0.2772 - accuracy: 0.9108
# Epoch 00088: val_loss did not improve from 1.13801
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 61ms/step - loss: 0.2770 - accuracy: 0.9109 - val_loss: 2.2989 - val_accuracy: 0.6354
# Epoch 89/100
# 403/404 [============================>.] - ETA: 0s - loss: 0.2699 - accuracy: 0.9145
# Epoch 00089: val_loss did not improve from 1.13801
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 61ms/step - loss: 0.2700 - accuracy: 0.9145 - val_loss: 2.3186 - val_accuracy: 0.6354
# Epoch 90/100
# 403/404 [============================>.] - ETA: 0s - loss: 0.2612 - accuracy: 0.9188
# Epoch 00090: val_loss did not improve from 1.13801
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 61ms/step - loss: 0.2617 - accuracy: 0.9188 - val_loss: 2.3515 - val_accuracy: 0.6381
# Epoch 91/100
# 403/404 [============================>.] - ETA: 0s - loss: 0.2604 - accuracy: 0.9188
# Epoch 00091: val_loss did not improve from 1.13801
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 61ms/step - loss: 0.2602 - accuracy: 0.9188 - val_loss: 2.3507 - val_accuracy: 0.6370
# Epoch 92/100
# 403/404 [============================>.] - ETA: 0s - loss: 0.2490 - accuracy: 0.9195
# Epoch 00092: val_loss did not improve from 1.13801
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 61ms/step - loss: 0.2490 - accuracy: 0.9195 - val_loss: 2.5505 - val_accuracy: 0.6401
# Epoch 93/100
# 403/404 [============================>.] - ETA: 0s - loss: 0.2557 - accuracy: 0.9170
# Epoch 00093: val_loss did not improve from 1.13801
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 61ms/step - loss: 0.2558 - accuracy: 0.9169 - val_loss: 2.5519 - val_accuracy: 0.6406
# Epoch 94/100
# 403/404 [============================>.] - ETA: 0s - loss: 0.2463 - accuracy: 0.9235
# Epoch 00094: val_loss did not improve from 1.13801
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 61ms/step - loss: 0.2460 - accuracy: 0.9236 - val_loss: 2.5003 - val_accuracy: 0.6410
# Epoch 95/100
# 403/404 [============================>.] - ETA: 0s - loss: 0.2460 - accuracy: 0.9216
# Epoch 00095: val_loss did not improve from 1.13801
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 61ms/step - loss: 0.2457 - accuracy: 0.9218 - val_loss: 2.3601 - val_accuracy: 0.6375
# Epoch 96/100
# 403/404 [============================>.] - ETA: 0s - loss: 0.2390 - accuracy: 0.9254
# Epoch 00096: val_loss did not improve from 1.13801
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 61ms/step - loss: 0.2389 - accuracy: 0.9254 - val_loss: 2.4828 - val_accuracy: 0.6413
# Epoch 97/100
# 403/404 [============================>.] - ETA: 0s - loss: 0.2353 - accuracy: 0.9282
# Epoch 00097: val_loss did not improve from 1.13801
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 61ms/step - loss: 0.2357 - accuracy: 0.9282 - val_loss: 2.4631 - val_accuracy: 0.6429
# Epoch 98/100
# 403/404 [============================>.] - ETA: 0s - loss: 0.2314 - accuracy: 0.9256
# Epoch 00098: val_loss did not improve from 1.13801
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 61ms/step - loss: 0.2311 - accuracy: 0.9257 - val_loss: 2.4886 - val_accuracy: 0.6407
# Epoch 99/100
# 403/404 [============================>.] - ETA: 0s - loss: 0.2271 - accuracy: 0.9285
# Epoch 00099: val_loss did not improve from 1.13801
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 61ms/step - loss: 0.2269 - accuracy: 0.9285 - val_loss: 2.5224 - val_accuracy: 0.6402
# Epoch 100/100
# 403/404 [============================>.] - ETA: 0s - loss: 0.2223 - accuracy: 0.9308
# Epoch 00100: val_loss did not improve from 1.13801
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 404/404 [==============================] - 25s 61ms/step - loss: 0.2224 - accuracy: 0.9307 - val_loss: 2.5696 - val_accuracy: 0.6404

# %%
print("Model accuracy  = ",max(model_info.history['accuracy']))
print("Validation accuracy  = ",max(model_info.history['val_accuracy']))
# Out:
# Model accuracy  =  0.930722177028656
# Validation accuracy  =  0.6428792476654053

# %%
import matplotlib.pyplot as plt
plt.plot(model_info.history['accuracy'])
plt.plot(model_info.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot(model_info.history['loss'])
plt.plot(model_info.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper center')
plt.show()

# %% [markdown]
# # Save the model

# %%
from keras.models import model_from_json
model_json = model.to_json()
with open("/content/gdrive/My Drive/Colab Notebooks/fer2/model.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("/content/gdrive/My Drive/Colab Notebooks/fer2/model.h5")
print("Saved model to disk")
# Out:
# Saved model to disk
